# %%
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist

nltk.download('punkt')
nltk.download('stopwords')

# Step 1: Paragraph
text = """
Artificial Intelligence (AI) is transforming the way we live and work. From smart assistants like Siri and Alexa to self-driving cars, AI is everywhere. 
It powers recommendation systems on Netflix and YouTube, helps doctors in diagnosis, and even creates music and art. 
This technology is growing rapidly and has the potential to surpass human abilities in some areas. 
However, ethical concerns and job displacement are major topics of discussion. AI is truly revolutionizing the future.
"""

# Step 1: Lowercase & remove punctuation
text_lower = text.lower()
text_no_punct = text_lower.translate(str.maketrans('', '', string.punctuation))

# Step 2: Tokenization
word_tokens = word_tokenize(text_no_punct)
sent_tokens = sent_tokenize(text)

# Step 3: Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in word_tokens if word not in stop_words]

# Step 4: Frequency Distribution
freq_dist = FreqDist(filtered_words)

print("Word Tokens:", word_tokens)
print("Sentence Tokens:", sent_tokens)
print("Filtered Words (No Stopwords):", filtered_words)
print("Frequency Distribution:")
freq_dist.plot(20, cumulative=False)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Word Tokens: ['artificial', 'intelligence', 'ai', 'is', 'transforming', 'the', 'way', 'we', 'live', 'and', 'work', 'from', 'smart', 'assistants', 'like', 'siri', 'and', 'alexa', 'to', 'selfdriving', 'cars', 'ai', 'is', 'everywhere', 'it', 'powers', 'recommendation', 'systems', 'on', 'netflix', 'and', 'youtube', 'helps', 'doctors', 'in', 'diagnosis', 'and', 'even', 'creates', 'music', 'and', 'art', 'this', 'technology', 'is', 'growing', 'rapidly', 'and', 'has', 'the', 'potential', 'to', 'surpass', 'human', 'abilities', 'in', 'some', 'areas', 'however', 'ethical', 'concerns', 'and', 'job', 'displacement', 'are', 'major', 'topics', 'of', 'discussion', 'ai', 'is', 'truly', 'revolutionizing', 'the', 'future']
# Sentence Tokens: ['\nArtificial Intelligence (AI) is transforming the way we live and work.', 'From smart assistants like Siri and Alexa to self-driving cars, AI is everywhere.', 'It powers recommendation systems on Netflix and YouTube, helps doctors in diagnosis, and even creates music and art.', 'This technology is growing rapidly and has the potential to surpass human abilities in some areas.', 'However, ethical concerns and job displacement are major topics of discussion.', 'AI is truly revolutionizing the future.']
# Filtered Words (No Stopwords): ['artificial', 'intelligence', 'ai', 'transforming', 'way', 'live', 'work', 'smart', 'assistants', 'like', 'siri', 'alexa', 'selfdriving', 'cars', 'ai', 'everywhere', 'powers', 'recommendation', 'systems', 'netflix', 'youtube', 'helps', 'doctors', 'diagnosis', 'even', 'creates', 'music', 'art', 'technology', 'growing', 'rapidly', 'potential', 'surpass', 'human', 'abilities', 'areas', 'however', 'ethical', 'concerns', 'job', 'displacement', 'major', 'topics', 'discussion', 'ai', 'truly', 'revolutionizing', 'future']
# Frequency Distribution:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')

porter = PorterStemmer()
lancaster = LancasterStemmer()
lemmatizer = WordNetLemmatizer()

porter_stemmed = [porter.stem(word) for word in filtered_words]
lancaster_stemmed = [lancaster.stem(word) for word in filtered_words]
lemmatized = [lemmatizer.lemmatize(word) for word in filtered_words]

print("Porter Stemmer:", porter_stemmed)
print("Lancaster Stemmer:", lancaster_stemmed)
print("Lemmatized:", lemmatized)
# Out:
# Porter Stemmer: ['artifici', 'intellig', 'ai', 'transform', 'way', 'live', 'work', 'smart', 'assist', 'like', 'siri', 'alexa', 'selfdriv', 'car', 'ai', 'everywher', 'power', 'recommend', 'system', 'netflix', 'youtub', 'help', 'doctor', 'diagnosi', 'even', 'creat', 'music', 'art', 'technolog', 'grow', 'rapidli', 'potenti', 'surpass', 'human', 'abil', 'area', 'howev', 'ethic', 'concern', 'job', 'displac', 'major', 'topic', 'discuss', 'ai', 'truli', 'revolution', 'futur']
# Lancaster Stemmer: ['art', 'intellig', 'ai', 'transform', 'way', 'liv', 'work', 'smart', 'assist', 'lik', 'sir', 'alex', 'selfdr', 'car', 'ai', 'everywh', 'pow', 'recommend', 'system', 'netflix', 'youtub', 'help', 'doct', 'diagnos', 'ev', 'cre', 'mus', 'art', 'technolog', 'grow', 'rapid', 'pot', 'surpass', 'hum', 'abl', 'area', 'howev', 'eth', 'concern', 'job', 'displac', 'maj', 'top', 'discuss', 'ai', 'tru', 'revolv', 'fut']
# Lemmatized: ['artificial', 'intelligence', 'ai', 'transforming', 'way', 'live', 'work', 'smart', 'assistant', 'like', 'siri', 'alexa', 'selfdriving', 'car', 'ai', 'everywhere', 'power', 'recommendation', 'system', 'netflix', 'youtube', 'help', 'doctor', 'diagnosis', 'even', 'creates', 'music', 'art', 'technology', 'growing', 'rapidly', 'potential', 'surpass', 'human', 'ability', 'area', 'however', 'ethical', 'concern', 'job', 'displacement', 'major', 'topic', 'discussion', 'ai', 'truly', 'revolutionizing', 'future']
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\sharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Step 1: Original Text
original_text = text

# a. Words > 5 letters
words_gt_5 = re.findall(r'\b\w{6,}\b', original_text)

# b. Numbers
numbers = re.findall(r'\b\d+\b', original_text)

# c. Capitalized Words
capitalized_words = re.findall(r'\b[A-Z][a-z]*\b', original_text)

# d. Split into words with only alphabets
alpha_words = re.findall(r'\b[a-zA-Z]+\b', original_text)

# e. Words starting with vowels
vowel_words = [word for word in alpha_words if word[0].lower() in 'aeiou']

print("Words > 5 letters:", words_gt_5)
print("Numbers:", numbers)
print("Capitalized Words:", capitalized_words)
print("Alphabet-only Words:", alpha_words)
print("Words Starting with Vowels:", vowel_words)
# Out:
# Words > 5 letters: ['Artificial', 'Intelligence', 'transforming', 'assistants', 'driving', 'everywhere', 'powers', 'recommendation', 'systems', 'Netflix', 'YouTube', 'doctors', 'diagnosis', 'creates', 'technology', 'growing', 'rapidly', 'potential', 'surpass', 'abilities', 'However', 'ethical', 'concerns', 'displacement', 'topics', 'discussion', 'revolutionizing', 'future']
# Numbers: []
# Capitalized Words: ['Artificial', 'Intelligence', 'From', 'Siri', 'Alexa', 'It', 'Netflix', 'This', 'However']
# Alphabet-only Words: ['Artificial', 'Intelligence', 'AI', 'is', 'transforming', 'the', 'way', 'we', 'live', 'and', 'work', 'From', 'smart', 'assistants', 'like', 'Siri', 'and', 'Alexa', 'to', 'self', 'driving', 'cars', 'AI', 'is', 'everywhere', 'It', 'powers', 'recommendation', 'systems', 'on', 'Netflix', 'and', 'YouTube', 'helps', 'doctors', 'in', 'diagnosis', 'and', 'even', 'creates', 'music', 'and', 'art', 'This', 'technology', 'is', 'growing', 'rapidly', 'and', 'has', 'the', 'potential', 'to', 'surpass', 'human', 'abilities', 'in', 'some', 'areas', 'However', 'ethical', 'concerns', 'and', 'job', 'displacement', 'are', 'major', 'topics', 'of', 'discussion', 'AI', 'is', 'truly', 'revolutionizing', 'the', 'future']
# Words Starting with Vowels: ['Artificial', 'Intelligence', 'AI', 'is', 'and', 'assistants', 'and', 'Alexa', 'AI', 'is', 'everywhere', 'It', 'on', 'and', 'in', 'and', 'even', 'and', 'art', 'is', 'and', 'abilities', 'in', 'areas', 'ethical', 'and', 'are', 'of', 'AI', 'is']

# %%
def custom_tokenizer(text):
    # Remove punctuation (keep contractions and hyphenated words)
    text = re.sub(r"[^\w\s\-']", ' ', text)
    
    # Keep decimal numbers intact
    text = re.sub(r'(?<=\d)\s(?=\d)', '', text)
    
    # Tokenize
    tokens = re.findall(r"\b\w+(?:[-']\w+)*\.?\w*\b", text)
    return tokens

# Regex substitutions
def regex_substitutions(text):
    # Email
    text = re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w{2,4}\b', '<EMAIL>', text)
    # URL
    text = re.sub(r'http[s]?://\S+|www\.\S+', '<URL>', text)
    # Phone numbers
    text = re.sub(r'\b(?:\+91\s?\d{10}|\d{3}[-.\s]?\d{3}[-.\s]?\d{4})\b', '<PHONE>', text)
    return text

custom_tokens = custom_tokenizer(text)
cleaned_text = regex_substitutions(text)

print("Custom Tokens:", custom_tokens)
print("Cleaned Text with Placeholders:")
print(cleaned_text)
# Out:
# Custom Tokens: ['Artificial', 'Intelligence', 'AI', 'is', 'transforming', 'the', 'way', 'we', 'live', 'and', 'work', 'From', 'smart', 'assistants', 'like', 'Siri', 'and', 'Alexa', 'to', 'self-driving', 'cars', 'AI', 'is', 'everywhere', 'It', 'powers', 'recommendation', 'systems', 'on', 'Netflix', 'and', 'YouTube', 'helps', 'doctors', 'in', 'diagnosis', 'and', 'even', 'creates', 'music', 'and', 'art', 'This', 'technology', 'is', 'growing', 'rapidly', 'and', 'has', 'the', 'potential', 'to', 'surpass', 'human', 'abilities', 'in', 'some', 'areas', 'However', 'ethical', 'concerns', 'and', 'job', 'displacement', 'are', 'major', 'topics', 'of', 'discussion', 'AI', 'is', 'truly', 'revolutionizing', 'the', 'future']
# Cleaned Text with Placeholders:
#
# Artificial Intelligence (AI) is transforming the way we live and work. From smart assistants like Siri and Alexa to self-driving cars, AI is everywhere.
# It powers recommendation systems on Netflix and YouTube, helps doctors in diagnosis, and even creates music and art.
# This technology is growing rapidly and has the potential to surpass human abilities in some areas.
# However, ethical concerns and job displacement are major topics of discussion. AI is truly revolutionizing the future.
