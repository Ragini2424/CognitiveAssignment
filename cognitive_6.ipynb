# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragini2424/CognitiveAssignment/blob/main/cognitive_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

M = float(input("Enter a value for M: "))

x = np.linspace(-10, 10, 400)

y1 = M * x**2
y2 = M * np.sin(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='Mx²', linestyle='--', color='b')
plt.plot(x, y2, label='Msin(x)', linestyle='-', color='r')

plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Plot of y = Mx² and y = Msin(x)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Enter a value for M: 10

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({'Subjects': ['Math', 'Science', 'English', 'History', 'Computer'],
                   'Scores': [85, 90, 78, 88, 95]})

ax = sns.barplot(x='Subjects', y='Scores', hue='Subjects', data=df, palette='viridis', legend=False)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=10, color='black')

plt.title('Scores by Subject')
plt.grid(axis='y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(102317266)

data = np.random.randn(50)
cumsum_data = np.cumsum(data)

fig, axes = plt.subplots(2, 2)

axes[0, 0].plot(cumsum_data, marker='o')
axes[0, 0].set_title('Cumulative Sum')
axes[0, 0].grid(True)

axes[0, 1].scatter(range(50), data, color='red')
axes[0, 1].set_title('Random Scatter')
axes[0, 1].grid(True)

axes[1, 0].axis('off')
axes[1, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from google.colab import files

uploaded = files.upload()

import pandas as pd

df = pd.read_csv("company_sales_data.csv")
df.head()

# **1. Line plot for Total Profit**
plt.plot(df['month_number'], df['total_profit'], marker='o', color='g')
plt.title("Total Profit Over Months")
plt.xlabel("Month"), plt.ylabel("Total Profit")
plt.xticks(rotation=45), plt.grid()
plt.show()

# **2. Multiline plot for product sales**
for col in df.columns[1:-1]:  # Skip 'Month' & 'Total_Profit'
    plt.plot(df['month_number'], df[col], marker='o', label=col)

plt.title("Product Sales Over Time")
plt.xlabel("Month"), plt.ylabel("Sales")
plt.xticks(rotation=45), plt.legend(), plt.grid()
plt.show()

# **3. Bar chart for all attributes**
df.set_index('month_number').plot(kind='bar', figsize=(8, 6))
plt.title("Sales Data Overview")
plt.grid()
plt.show()
# Out:
#      <input type="file" id="files-21595dad-47e7-43ba-9e75-6593f1bbe530" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21595dad-47e7-43ba-9e75-6593f1bbe530">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
