# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragini2424/CognitiveAssignment/blob/main/cognitive_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
i. Sum of all elements
ii. Sum of all elements row-wise
iii. Sum of all elements column-wise '''

import numpy as np

gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')

total_sum = np.sum(gfg)

row_sum = np.sum(gfg, axis=1)

col_sum = np.sum(gfg, axis=0)

print("Sum of all elements:", total_sum)
print("Sum of all elements row-wise:\n", row_sum)
print("Sum of all elements column-wise:\n", col_sum)
# Out:
# Sum of all elements: 45
# Sum of all elements row-wise:
#  [[14]
#  [16]
#  [15]]
# Sum of all elements column-wise:
#  [[20  9 16]]

# %%
'''Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
i. Sorted array
ii. Indices of sorted array
iii. 4 smallest elements
iv. 5 largest elements '''
import numpy as np

array = np.array([10, 52, 62, 16, 16, 54, 453])

sorted_array = np.sort(array)

sorted_indices = np.argsort(array)

smallest_4 = np.sort(array)[:4]

largest_5 = np.sort(array)[-5:]

print("Sorted array:", sorted_array)
print("Indices of sorted array:", sorted_indices)
print("4 smallest elements:", smallest_4)
print("5 largest elements:", largest_5)

'''
(b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
i. Integer elements only
ii. Float elements only'''
array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])

integer_elements = array[array == array.astype(int)]

float_elements = array[array != array.astype(int)]

print("Integer elements only:", integer_elements)
print("Float elements only:", float_elements)
# Out:
# Sorted array: [ 10  16  16  52  54  62 453]
# Indices of sorted array: [0 3 4 1 5 2 6]
# 4 smallest elements: [10 16 16 52]
# 5 largest elements: [ 16  52  54  62 453]
# Integer elements only: [1. 2. 3. 2.]
# Float elements only: [1.2 2.2]

# %%
'''Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
each function from the list below and compute y values using NumPy:
 Y = x2
 Y = sin(x)
 Y = ex
 Y = log(|x| + 1)
Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.'''

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y1 = x**2             # Y = x^2
y2 = np.sin(x)        # Y = sin(x)
y3 = np.exp(x)        # Y = e^x
y4 = np.log(np.abs(x) + 1)  # Y = log(|x| + 1)

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label=r'$y = x^2$', linestyle='-', color='blue')
plt.plot(x, y2, label=r'$y = \sin(x)$', linestyle='--', color='red')
plt.plot(x, y3, label=r'$y = e^x$', linestyle='-.', color='green')
plt.plot(x, y4, label=r'$y = \log(|x| + 1)$', linestyle=':', color='purple')

plt.title("Plots of Different Functions", fontsize=14)
plt.xlabel("x values", fontsize=12)
plt.ylabel("y values", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.show()

# %%
'''using NumPy broadcasting.
a) Generate your unique sales dataset:
 Take the sum of the ASCII values of the initials of your first and last
name. Call this value X. (If your initials are A B → ASCII sum = 65
+ 66 = 131 → sales = [131, 181, 231, 281, 331].)
 Create a NumPy array sales with values [X, X+50, X+100, X+150,
X+200].
b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
 Use broadcasting to apply this tax rate to each sales value.
c) Adjust sales based on discount:
 If sales < X+100, apply a 5% discount.
 If sales >= X+100, apply a 10% discount.
d) Expand sales data for multiple weeks:
 Create a 3×5 matrix representing three weeks of sales by stacking
sales three times using broadcasting.
 Increase sales by 2% per week using element-wise broadcasting.'''
import numpy as np

# (a) Generate sales dataset
X = ord('R') + ord('S')
sales = np.array([X, X+50, X+100, X+150, X+200])

# (b) Compute tax and apply it
tax_rate = ((X % 5) + 5) / 100
sales_after_tax = sales * (1 + tax_rate)

# (c) Apply discount
discounted_sales = np.where(sales < (X + 100), sales * 0.95, sales * 0.90)


weekly_sales = np.tile(sales, (3, 1))

weeks = np.arange(3).reshape(3, 1)  # Create an array: [[0], [1], [2]]
growth_factor = 1 + (weeks * 0.02)  # Growth factor for each week (1st week: 1.00, 2nd: 1.02, 3rd: 1.04)

final_weekly_sales = weekly_sales * growth_factor

print("Sales:", sales)
print("Sales After Tax:", sales_after_tax)
print("Discounted Sales:", discounted_sales)
print("Weekly Sales Data (Before Growth):\n", weekly_sales)
print("Final Weekly Sales Data (After Growth):\n", final_weekly_sales)
# Out:
# Sales: [165 215 265 315 365]
# Sales After Tax: [173.25 225.75 278.25 330.75 383.25]
# Discounted Sales: [156.75 204.25 238.5  283.5  328.5 ]
# Weekly Sales Data (Before Growth):
#  [[165 215 265 315 365]
#  [165 215 265 315 365]
#  [165 215 265 315 365]]
# Final Weekly Sales Data (After Growth):
#  [[165.  215.  265.  315.  365. ]
#  [168.3 219.3 270.3 321.3 372.3]
#  [171.6 223.6 275.6 327.6 379.6]]
